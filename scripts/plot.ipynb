# %%
import matplotlib.pyplot as plt
import glob
import json
import numpy as np

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/stack_*_test_*/010/partition_010_ops_6_split_0_0.log"
small_times_partition, small_crs_partition, medium_times_partition, medium_crs_partition = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times_partition.append(time)
            medium_crs_partition.append(cr)
        elif "_18_" in f:
            small_times_partition.append(time)
            small_crs_partition.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/*_ht_eps_010/010/beam_010_ops_6_split_5.log"
small_times, small_crs, medium_times, medium_crs = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times.append(time)
            medium_crs.append(cr)
        elif "_18_" in f:
            small_times.append(time)
            small_crs.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/*_ht_eps_010/010/beam_010_ops_6_split_0.log"
small_times_greedy, small_crs_greedy, medium_times_greedy, medium_crs_greedy = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times_greedy.append(time)
            medium_crs_greedy.append(cr)
        elif "_18_" in f:
            small_times_greedy.append(time)
            small_crs_greedy.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/*_test_[0-9]/010/beam_010_ops_6_split_5.log"
small_times_core, small_crs_core, medium_times_core, medium_crs_core = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times_core.append(time)
            medium_crs_core.append(cr)
        elif "_18_" in f:
            small_times_core.append(time)
            small_crs_core.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/*_test_[0-9]/010/beam_010_ops_6_split_0.log"
small_times_core_greedy, small_crs_core_greedy, medium_times_core_greedy, medium_crs_core_greedy = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times_core_greedy.append(time)
            medium_crs_core_greedy.append(cr)
        elif "_18_" in f:
            small_times_core_greedy.append(time)
            small_crs_core_greedy.append(cr)

# %%
plt.scatter(small_times, small_crs, label="from HT + error split", marker="+")
plt.scatter(small_times_greedy, small_crs_greedy, label="from HT + greedy error", marker="x")
plt.scatter(small_times_core, small_crs_core, label="from core + error split", marker="1")
plt.scatter(small_times_core_greedy, small_crs_core_greedy, label="from core + greedy error", marker="2")
plt.scatter(small_times_partition, small_crs_partition, label="partition", marker="3")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
plt.title("Shape: 18x120x120x12")
# plt.xscale("log")
plt.legend(loc="upper center")
plt.show()

# %%
plt.scatter(medium_times, medium_crs, label="from HT + error split", marker="v")
plt.scatter(medium_times_greedy, medium_crs_greedy, label="from HT + greedy error", marker="s")
plt.scatter(medium_times_core, medium_crs_core, label="from core + error split", marker="o")
plt.scatter(medium_times_core_greedy, medium_crs_core_greedy, label="from core + greedy error", marker="*")
plt.scatter(medium_times_partition, medium_crs_partition, label="partition", marker="D")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
# plt.xscale("log")
plt.title("Shape: 17x11x120x120x12")
plt.legend()
plt.show()

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/stack_*_[0-9]/005/beam_005_ht_ops_6_split_5_0.log"
small_times, small_crs, medium_times, medium_crs = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times.append(time)
            medium_crs.append(cr)
        elif "_18_" in f:
            small_times.append(time)
            small_crs.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/stack_*_[0-9]/005/beam_005_ht_ops_6_split_0_0.log"
small_times_greedy, small_crs_greedy, medium_times_greedy, medium_crs_greedy = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times_greedy.append(time)
            medium_crs_greedy.append(cr)
        elif "_18_" in f:
            small_times_greedy.append(time)
            small_crs_greedy.append(cr)
# Out:
# ../output/BigEarthNet-v1_0_stack/stack_18_test_2/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_187_test_6/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_18_test_5/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_187_test_1/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_187_test_8/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_187_test_9/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_18_test_4/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_187_test_0/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_18_test_3/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_187_test_7/005/beam_005_ht_ops_6_split_0_0.log
# ../output/BigEarthNet-v1_0_stack/stack_18_test_6/005/beam_005_ht_ops_6_split_0_0.log
# ...

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/*_test_[0-9]/005/beam_005_ops_6_split_5_0.log"
small_times_core, small_crs_core, medium_times_core, medium_crs_core = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times_core.append(time)
            medium_crs_core.append(cr)
        elif "_18_" in f:
            small_times_core.append(time)
            small_crs_core.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/*_test_[0-9]/005/beam_005_ops_6_split_0_0.log"
small_times_core_greedy, small_crs_core_greedy, medium_times_core_greedy, medium_crs_core_greedy = [], [], [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        if "_187_" in f:
            medium_times_core_greedy.append(time)
            medium_crs_core_greedy.append(cr)
        elif "_18_" in f:
            small_times_core_greedy.append(time)
            small_crs_core_greedy.append(cr)

# %%
plt.scatter(small_times, small_crs, label="from HT + error split", marker="+")
plt.scatter(small_times_greedy, small_crs_greedy, label="from HT + greedy error", marker="x")
plt.scatter(small_times_core, small_crs_core, label="from core + error split", marker="1")
plt.scatter(small_times_core_greedy, small_crs_core_greedy, label="from core + greedy error", marker="2")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
plt.title("Shape: 18x120x120x12")
# plt.xscale("log")
plt.legend(loc="upper center")
plt.show()

# %%
plt.scatter(medium_times, medium_crs, label="from HT + error split", marker="v")
plt.scatter(medium_times_greedy, medium_crs_greedy, label="from HT + greedy error", marker="s")
plt.scatter(medium_times_core, medium_crs_core, label="from core + error split", marker="o")
plt.scatter(medium_times_core_greedy, medium_crs_core_greedy, label="from core + greedy error", marker="*")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
# plt.xscale("log")
plt.title("Shape: 17x11x120x120x12")
plt.legend()
plt.show()

# %%
log_pattern = "../output/BigEarthNet-v1_0_all/*_test_[0-9]_ht_eps_010/010/beam_010_ops_6_split_5.log"
large_times, large_crs = [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        large_times.append(time)
        large_crs.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_all/*_test_[0-9]_ht_eps_010/010/beam_010_ops_6_split_0.log"
large_times_greedy, large_crs_greedy = [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(",")
        time = float(fields[1])
        
        cr = float(fields[3])

        large_times_greedy.append(time)
        large_crs_greedy.append(cr)

# %%
log_pattern = "../output/BigEarthNet-v1_0_all/*_test_[0-9]/010/htucker_textfile/ht.txt"
large_times_ht, large_crs_ht = [], []
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        fields = log_file.read().split(' ')
        time = float(fields[5])
        
        cr = float(fields[4])

        large_times_ht.append(time)
        large_crs_ht.append(cr)

# %%
plt.scatter(large_times, large_crs, label="from HT + error split", marker="v")
plt.scatter(large_times_greedy, large_crs_greedy, label="from HT + greedy error", marker="s")
plt.scatter(large_times_ht, large_crs_ht, label="HT", marker="o")
# plt.scatter(medium_times_core_greedy, medium_crs_core_greedy, label="from core + greedy error", marker="*")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
# plt.xscale("log")
plt.title("3360x120x120x12 (reshaped into different shapes)")
plt.legend()
plt.show()

# %%
import numpy as np

log_pattern = "../output/BigEarthNet-v1_0_stack/stack_18_test_[0-9]/010/beam_010_ht_ops_15_split_5_0_all.log"
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        stats = json.load(log_file)
        times, crs = zip(*stats[0]["compression"])
        crs = np.array(crs)
        crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
        plt.scatter(times, crs)
        plt.show()

# %%
import json
from benchmarks.benchmark import *
for f in glob.glob("../benchmarks/random/fctn_[4-5]_*/original.json"):
  with open(f, "r") as json_file:
    bd = json.load(json_file)
    b = Benchmark(**bd)
    print(f.split("/")[-2], b.to_network().cost())
# Out:
# fctn_5_20_1 9360
# fctn_5_20_0 11960
# fctn_4_20_0 1960
# fctn_4_20_1 1520
# fctn_5_20_2 5280
# fctn_5_20_4 4620
# fctn_5_20_3 8480
# fctn_4_20_3 2160
# fctn_4_20_4 2960
# fctn_4_20_2 2520

# %%
import numpy as np

x = np.random.randn(3,4)
xu, xs, xv = np.linalg.svd(x)

# %%
print(xu)
print(xs)
print(xv)
# Out:
# [[ 0.49548722 -0.84185782 -0.21393416]
#  [-0.22201163  0.11537094 -0.96819439]
#  [-0.83976381 -0.52722382  0.1297374 ]]
# [1.83586978 0.78749414 0.39061897]
# [[-0.3388143   0.75904737  0.55161604  0.06907748]
#  [-0.83119448 -0.09508602 -0.42324428  0.34776236]
#  [ 0.17808635  0.62200745 -0.71252962 -0.27146551]
#  [ 0.40324416  0.16707023 -0.09426326  0.89476037]]

# %%
y = np.tile(x, (3,3))
print(y.shape, y)
# Out:
# (9, 12) [[ 0.22796258  0.70152637  0.84191454 -0.14503005  0.22796258  0.70152637
#    0.84191454 -0.14503005  0.22796258  0.70152637  0.84191454 -0.14503005]
#  [-0.00477324 -0.553255    0.00619168  0.1061076  -0.00477324 -0.553255
#    0.00619168  0.1061076  -0.00477324 -0.553255    0.00619168  0.1061076 ]
#  [ 0.87647407 -1.09922068 -0.71080932 -0.2646398   0.87647407 -1.09922068
#   -0.71080932 -0.2646398   0.87647407 -1.09922068 -0.71080932 -0.2646398 ]
#  [ 0.22796258  0.70152637  0.84191454 -0.14503005  0.22796258  0.70152637
#    0.84191454 -0.14503005  0.22796258  0.70152637  0.84191454 -0.14503005]
#  [-0.00477324 -0.553255    0.00619168  0.1061076  -0.00477324 -0.553255
#    0.00619168  0.1061076  -0.00477324 -0.553255    0.00619168  0.1061076 ]
#  [ 0.87647407 -1.09922068 -0.71080932 -0.2646398   0.87647407 -1.09922068
#   -0.71080932 -0.2646398   0.87647407 -1.09922068 -0.71080932 -0.2646398 ]
#  [ 0.22796258  0.70152637  0.84191454 -0.14503005  0.22796258  0.70152637
# ...

# %%
yu, ys, yv = np.linalg.svd(y)
print(ys)
# Out:
# [5.50760934e+00 2.36248242e+00 1.17185690e+00 2.27572131e-16
#  1.33829270e-16 3.59356652e-17 1.11294231e-32 2.08326367e-33
#  4.36314097e-34]

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/stack_18_test_[0-9]/010/beam_010_ht_ops_6_split_0_0_all.log"
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        stats = json.load(log_file)
        times, crs = zip(*stats[0]["compression"])
        crs = np.maximum.accumulate(np.array(crs))
        crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
        plt.scatter(times, crs)
        plt.xlabel("Time (s)")
        plt.ylabel("Compression")
        plt.show()

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/stack_187_test_[0-9]/010/beam_010_ht_ops_6_split_5_0_all.log"
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        stats = json.load(log_file)
        times, crs = zip(*stats[0]["compression"])
        crs = np.maximum.accumulate(np.array(crs))
        crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
        plt.scatter(times, crs, label="error split = 5")

    f0 = f[:-11] + "0" + f[-10:]
    with open(f0, "r") as log_file:
        stats = json.load(log_file)
        times, crs = zip(*stats[0]["compression"])
        crs = np.maximum.accumulate(np.array(crs))
        crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
        plt.scatter(times, crs, label="error split = 0")

    plt.xlabel("Time (s)")
    plt.ylabel("Compression")
    plt.legend()
    plt.show()

# %%
log_pattern = "../output/BigEarthNet-v1_0_stack/stack_18_test_[0-9]/010/beam_010_ht_ops_6_split_5_0_all.log"
for f in glob.glob(log_pattern):
    with open(f, "r") as log_file:
        stats = json.load(log_file)
        times, crs = zip(*stats[0]["compression"])
        crs = np.maximum.accumulate(np.array(crs))
        crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
        plt.scatter(times, crs, label="error split = 5")

    f0 = f[:-11] + "0" + f[-10:]
    with open(f0, "r") as log_file:
        stats = json.load(log_file)
        times, crs = zip(*stats[0]["compression"])
        crs = np.maximum.accumulate(np.array(crs))
        crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
        plt.scatter(times, crs, label="error split = 0")

    plt.xlabel("Time (s)")
    plt.ylabel("Compression")
    plt.legend()
    plt.show()

# %%
with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/dfs_010_ops_6_split_0_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, costs = zip(*stats[0]["best_cost"])
    costs = np.minimum.accumulate(np.array(costs))
    best_cost = costs[-1]
    worst_cost = stats[0]["cr_core"] * best_cost
    crs = worst_cost / costs
    plt.scatter(times, crs, label="dfs split=0")

# with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/dfs_010_ops_6_split_5_0_all.log", "r") as log_file:
#     stats = json.load(log_file)
#     times, costs = zip(*stats[0]["best_cost"])
#     costs = np.minimum.accumulate(np.array(costs))
#     best_cost = costs[-1]
#     worst_cost = stats[0]["cr_core"] * best_cost
#     crs = worst_cost / costs
#     plt.scatter(times, crs, label="dfs split=5")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/beam_010_ops_6_split_0_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.maximum.accumulate(np.array(crs))
    crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
    plt.scatter(times, crs, label="beam split=0")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/beam_010_ops_6_split_5_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.maximum.accumulate(np.array(crs))
    crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
    plt.scatter(times, crs, label="beam split=5")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/beam_010_ops_6_split_10_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.maximum.accumulate(np.array(crs))
    crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
    plt.scatter(times, crs, label="beam split=10")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/beam_010_ht_ops_6_split_5_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.maximum.accumulate(np.array(crs))
    crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
    plt.scatter(times, crs, label="beam ht split=5")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/beam_010_ht_ops_6_split_0_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.maximum.accumulate(np.array(crs))
    crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
    plt.scatter(times, crs, label="beam ht split=0")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
plt.legend()
plt.show()

# %%
with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/dfs_010_ops_6_split_0_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, costs = zip(*stats[0]["best_cost"])
    costs = np.minimum.accumulate(np.array(costs))
    best_cost = costs[-1]
    worst_cost = stats[0]["cr_core"] * best_cost
    crs = worst_cost / costs
    plt.scatter(times, crs, label="dfs split=0")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/dfs_010_ops_6_split_5_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, costs = zip(*stats[0]["best_cost"])
    costs = np.minimum.accumulate(np.array(costs))
    best_cost = costs[-1]
    worst_cost = stats[0]["cr_core"] * best_cost
    crs = worst_cost / costs
    plt.scatter(times, crs, label="dfs split=5")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/beam_010_ops_6_split_0_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.maximum.accumulate(np.array(crs))
    crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
    plt.scatter(times, crs, label="beam split=0")

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/beam_010_ops_6_split_5_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.maximum.accumulate(np.array(crs))
    crs = crs * stats[0]["cr_core"] / stats[0]["cr_start"]
    plt.scatter(times, crs, label="beam split=5")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from pytens.algs import *

x = np.load("../data/BigEarthNet-v1_0_stack/stack_18_test_2/data.npy")
x_indices = [
    Index("I0", 18),
    Index("I1", 120),
    Index("I2", 120),
    Index("I3", 12),
]
delta = np.linalg.norm(x) * 0.1

# split into tt
s0 = np.linalg.svdvals(x.reshape(18, -1))
r0_ps = [s / (np.linalg.norm(x) ** 2) for s in np.cumsum(np.flip(s0) ** 2) if s <= delta ** 2]
r0 = Index("r0", (18-len(r0_ps), 18+1))
plt.plot([0] + r0_ps, label="r0=[18,120x120x12]")
# plt.show()

s1 = np.linalg.svdvals(x.transpose(1,0,2,3).reshape(120, -1))
r1_ps = [s/ (np.linalg.norm(x) ** 2) for s in np.cumsum(np.flip(s1) ** 2) if s <= delta ** 2]
r1 = Index("r1", (120-len(r1_ps), 120+1))
plt.plot([0] + r1_ps, label="r1=[120,18x120x12]")
plt.show()

s2 = np.linalg.svdvals(x.transpose(2,0,1,3).reshape(120, -1))
r2_ps = [s for s in np.cumsum(np.flip(s2) ** 2) if s <= delta ** 2]
r2 = Index("r2", (120-len(r2_ps), 120+1))
plt.plot([0] + r2_ps, label="r2=[120,18x120x12]")
plt.show()

s3 = np.linalg.svdvals(x.transpose(3,0,1,2).reshape(12, -1))
r3_ps = [s for s in np.cumsum(np.flip(s3) ** 2) if s <= delta ** 2]
r3 = Index("r3", (12-len(r3_ps), 12+1))
plt.plot([0] + r3_ps, label="r3=[12,18x120x120]")
plt.show()

s4 = np.linalg.svdvals(x.transpose(0,3,1,2).reshape(18*12, -1))
r4_ps = [s for s in np.cumsum(np.flip(s4) ** 2) if s <= delta ** 2]
r4 = Index("r4", (18*12-len(r4_ps), 18*12+1))
plt.plot([0] + r4_ps, label="r4=[18x12,120x120]")
# plt.legend()
plt.show()

# %%
import json

with open("../output/BigEarthNet-v1_0_stack/stack_187_test_6/010/partition_010_ops_6_split_0_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.minimum.accumulate(np.array(crs))
    crs = (187*120*120*12)/crs
    plt.scatter(times, crs, label="partition split=5")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
plt.legend()
plt.show()

# %%
import json

with open("../output/BigEarthNet-v1_0_stack/stack_18_test_2/010/partition_010_ops_6_split_0_0_all.log", "r") as log_file:
    stats = json.load(log_file)
    times, crs = zip(*stats[0]["compression"])
    crs = np.minimum.accumulate(np.array(crs))
    crs = (18*120*120*12)/crs
    plt.scatter(times, crs, label="partition split=5")

plt.xlabel("Time (s)")
plt.ylabel("Compression")
plt.legend()
plt.show()
